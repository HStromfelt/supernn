# %% [markdown]
# # Intro

# %% [markdown]
# ## Notes
#
# - All imports necessary for the cell are made in the cell, that way never have to run around running cells in a special order!
#  - However! Do need to run the main setup first so the root logger gets set
#
# - Also, when running the setup a bunch of times, many loggers seem to get made and the outputs get sent out many times...

# %% [markdown]
# # Experiment

# %% [markdown]
# ## Setup Logger and Other important stuff

# %%
# Automatically call debugger on uncaught exception
# %pdb on

import os, os.path
from supernn.admin import Log

## Init: Main Setup
log_dir = os.path.join(os.getcwd(), '../data/trial')
debug_mode = True
generate_log_dir = True
config_path = './config.ini'

args = dict(
    log_dir=log_dir,
    debug_mode=debug_mode,
    gen_log_dir=generate_log_dir,
    config_path=config_path
)

## Init: Set up logger
name = 'error_ordering_abs_incomp'  # Usually set when starting program from command line
prefix = name + '_supernn' if name != '' else supernn

args['name'] = name
args['prefix'] = prefix

log = Log.setup_log_with_args(args)
if not args['debug_mode']:
    log.info('Running in INFO mode')
    
# Copy code to dir so experiment can easily be run again
# !jupyter nbconvert --to python coping_just_error.ipynb
# !mv ./coping_just_error.py $Log.log_dir
# !cp $config_path $Log.log_dir
# Out:
# 10:57:18 [supernn.admin.log   ] [DEBUG   ] : Using tcmalloc!
# 10:57:18 [supernn.admin.log   ] [DEBUG   ] : Using tcmalloc!
# 10:57:18 [supernn.admin.log   ] [DEBUG   ] : Using tcmalloc!
# 10:57:18 [supernn.admin.log   ] [DEBUG   ] : Using tcmalloc!
# 10:57:18 [supernn.admin.log   ] [DEBUG   ] : Using tcmalloc!
# 10:57:18 [supernn.admin.log   ] [DEBUG   ] : Using tcmalloc!
# Automatic pdb calling has been turned ON
# [NbConvertApp] Converting notebook coping_just_error.ipynb to python
# [NbConvertApp] Writing 23732 bytes to coping_just_error.py

# %% [markdown]
# ## Base Runner

# %%
import time
import inspect

import supernn.util as util
from supernn.admin import Reporter, Experiment, Log
from supernn.nn import GraphConstructor, Activations; activations = Activations().__dict__
from supernn.datasets import DataInterface

class Runner(Experiment):
    """Parse config and then prepare/run the extracted experiments"""
    
    def __init__(self, config_path, experiment_name):
        """
        Experiment superclass __init__ provides:
            config_manager: Class that interfaces with .ini 
                config file and allows us to get different config parameters
            exp_configs: Config per experiment, obtained by running the 
                parse_experiments_config function which needs to be declared here
        """
        super().__init__(config_path, experiment_name)
        
    # Overriding from Experiment ~Abstract class
    def parse_experiments_config(self):
        """Unpack config"""
        log.info('===Parsing Experiment Config===')
        experiments = []
        
        # Dataset (loaded from corresponding data loader in lib)
        dataset = self.config_manager.get_config('dataset')
        
        # 2D Convolution (1)
        conv2d_1_detail = self.config_manager.get_config('conv2d_1', as_type=int)
        conv2d_1_activation = activations[self.config_manager.get_config('conv2d_1_activation')]
        conv2d_1 = dict(
            x = conv2d_1_detail[0],
            y = conv2d_1_detail[1],
            channels = conv2d_1_detail[2],
            features = conv2d_1_detail[3],
            activation = conv2d_1_activation
        )
        
        # 2D Convolution (2)
        conv2d_2_detail = self.config_manager.get_config('conv2d_2', as_type=int)
        conv2d_2_activation = activations[self.config_manager.get_config('conv2d_2_activation')]
        conv2d_2 = dict(
            x = conv2d_2_detail[0],
            y = conv2d_2_detail[1],
            channels = conv2d_2_detail[2],
            features = conv2d_2_detail[3],
            activation = conv2d_2_activation
        )
        
        # Fully connected Layer
        fcon_1 = dict(
            nodes = self.config_manager.get_config('fcon_1', as_type=int),
            activation = activations[self.config_manager.get_config('fcon_1_activation')]
        )
        
        # Hyperparameters
        learning_rate = self.config_manager.get_config('base_learning_rate', as_type=float)
        batch_size = self.config_manager.get_config('batch_size', as_type=int)
        max_steps = self.config_manager.get_config('max_steps', as_type=int)
        optimiser = self.config_manager.get_config('optimiser')
        
        name = 'conv_lr_{}'.format(learning_rate)
        
        args = dict(
            dataset=dataset,
            conv2d_1=conv2d_1,
            conv2d_2=conv2d_2,
            fcon_1=fcon_1,
            learning_rate=learning_rate,
            batch_size=batch_size,
            max_steps=max_steps,
            optimiser=optimiser,
            name=name
        )
        
        experiments.append(args)
        
        return experiments
    
    def run(self):
        start = time.time()
        for exp_args in self.exp_configs:
            log.debug('Running experiment with args: {}'.format(exp_args))
            self.run_experiment(exp_args)
        log.debug('Finished experiments after %.2fs', time.time() - start)
    
    def run_experiment(self, config):
        start = time.time()
        # prepare savable config
        s_config = {k: (v if not callable(v) else v.__name__) for k, v in config.items()}
        log.debug('experiment config: {}'.format(s_config))
        self.save_subexp_config(s_config, s_config['name'] + '/')
        
        config['data_interface'] = DataInterface(data_name=config['dataset'])
        
        # Set where tensorboard output should go. 
        # Name usually dictated by commandline input,
        # but here it is set in above cell
        Reporter.set_tensorboard_dir(Log.log_dir + 'tensorboard_{}/'.format(config['name']))
        
        # This runs the learner process
        Learner(config).run()
            
        
        log.debug('Finished experiment after %.2fs', time.time() - start)

# %% [markdown]
# ## Graph Runner

# %%
from IPython.core.debugger import set_trace

import tensorflow as tf
import numpy as np
import time

from supernn.admin import Reporter, SystemStats, Log; log = Log.get_logger(__name__)
from supernn.nn import InputLayer, FullyConnected, Convolution2D, OutputLayer

## Responsible for taking config and running the experiment
class Learner(object):
    
    def __init__(self, args):
        self.args = args
        self.metrics = None  # tensorflow metrics/ops for model to function
        
        self.graphs = dict(
            tensorflow=None,
            conv2d_graph=None
        )
    
    def run(self):
        # Setup model and graph
        tf_graph = tf.Graph()
        self.graphs['tensorflow'] = tf_graph  # Incase we start using more than one graph.. bcz ideazzzzzzzz
        with tf_graph.as_default():
            self.prepare_data_loader()
            self.build_model()  # sets custom graph
            self.assign_metrics() 
            self.create_and_run_session()
    
    #####
    
    def prepare_data_loader(self):
        self.args['input_data'] = self.args['data_interface'].loader.load_data()
    
    def build_model(self):
        """Test Graph Constructor"""
        log.debug('===Constructing Graph===')
        
        graph = GraphConstructor()
        
        # Data interface, 
        data_interface = self.args['data_interface']
        dataset = data_interface.dataset
        
        
        # Layer Config
        # input_dict
        input_1 = InputLayer(
            dataset['shape'][0], 
            dataset['dtype'], 
            layer_type=dataset['shape_type'], 
            toConv='conv2d',  # conv2d as next layer is a conv2d
            data_interface=data_interface, 
            name='input'
        )
        
        # conv_dict
        conv2d_1 = Convolution2D(
            self.args['conv2d_1']['activation'], 
            self.args['conv2d_1']['x'], 
            self.args['conv2d_1']['y'], 
            self.args['conv2d_1']['channels'], 
            self.args['conv2d_1']['features'], 
            prev_layer='input', 
            name='conv2d_1'
        )
        
        conv2d_2 = Convolution2D(
            self.args['conv2d_2']['activation'], 
            self.args['conv2d_2']['x'], 
            self.args['conv2d_2']['y'], 
            self.args['conv2d_2']['channels'], 
            self.args['conv2d_2']['features'], 
            prev_layer='conv2d_1', 
            name='conv2d_2'
        )
        
        # fully_con_dict
        fCon_1 = FullyConnected(
            self.args['fcon_1']['activation'], 
            self.args['fcon_1']['nodes'], 
            'conv2d_2', 
            name='fcon_1'
        )
        
        # out_dict TODO:: Nothing in config for output... can there be anything useful there?
        out_1 = OutputLayer(
            tf.matmul, 
            10, 
            prev_layer='fcon_1', 
            name='out_1'
        )

        graph.generate_graph_structure(
            properties=[
                ('input', input_1), 
                ('conv2d', conv2d_1), 
                ('conv2d', conv2d_2), 
                ('fully_connected', fCon_1), 
                ('output', out_1)
            ]
        )
    
        self.graphs['conv2d_graph'] = graph
        
    def assign_metrics(self):
        log.info('===Assigning metrics===')
        # Specify metrics
        target_output = tf.placeholder(
            tf.float32, 
            shape=[
                None, 
                self.graphs['conv2d_graph'].model.model_named_layers['out_1'].output.get_shape().as_list()[1]
            ]
        )
        predicted_output = self.graphs['conv2d_graph'].model.model_named_layers['out_1'].output

        with tf.name_scope('cross_entropy'):
            diff = tf.nn.softmax_cross_entropy_with_logits(labels=target_output, logits=predicted_output)
            with tf.name_scope('total'):
                loss = tf.reduce_mean(diff)
        Reporter.report_scalar(loss, 'cross_entropy')

        with tf.name_scope('accuracy'):
            with tf.name_scope('correct_prediction'):
                correct_prediction = tf.equal(tf.argmax(predicted_output, 1), tf.argmax(target_output, 1))
            with tf.name_scope('accuracy'):
                accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        Reporter.report_scalar(accuracy, 'accuracy')

        merger = Reporter.merge_summaries()
        
        train_step = tf.train.AdamOptimizer(1e-4).minimize(loss)
        x = self.graphs['conv2d_graph'].model.model_named_layers['input'].input_data
        
        ## Append metrics to experiment arguments (Necessary for session runner)
        self.args['x'] = x
        self.args['train_step'] = train_step
        self.args['merger'] = merger
        self.args['accuracy'] = accuracy
        self.args['target_output'] = target_output
        self.args['predicted_output'] = predicted_output
    
    def create_and_run_session(self):
        log.info('===Preparing Session and Running===')
        
        # For clarity, unwrapping some args
        mnist = self.args['input_data']
        train_step = self.args['train_step']
        merger = self.args['merger']
        target_output = self.args['target_output']
        predicted_output = self.args['predicted_output']
        x = self.args['x']
        accuracy = self.args['accuracy']
        
        # Intialising important variables
        pass_schedule = ['Full', 'Prioritised', 'Full']  # Full pass (Standard batching), Ordered pass (follow new batches)
        prioritised_batch_sets = []
        is_custom_pass = False
        custom_batch = None
        batches_in_epoch = int(mnist.train.num_examples/self.args['batch_size'])
        
        # Helper function - Better in scope for variables access
        def feed_dict(train, custom=False, custom_batch=None):
            """Generate Tensorflow feed_dict: maps data onto Tensor placeholders."""
            if train:
                if custom:
                    # do stuff with custom batch
                    xs, ys = custom_batch
                else:
                    xs, ys = mnist.train.next_batch(self.args['batch_size'])
            else:
                xs, ys = mnist.test.images, mnist.test.labels
            # Load values into Tensorflow variables (accessible in instance args)
            return {x: xs, target_output: ys}
        
        
        with tf.Session() as sess:
            # Initialise all tensorflow variables (otherwise cannot use them)
            sess.run(tf.global_variables_initializer())
            
            # Set up Tensorboard
            train_writer = Reporter.set_writer_path('train', sess.graph)
            test_writer = Reporter.set_writer_path('test')
            sys_stats_writer = SystemStats(Reporter.set_writer_path('performance'))
            
            Reporter.set_saver(tf.train.Saver())
            
            # Main loop
            for epoch in range(len(pass_schedule)):  # Loop while schedules not finished
                # TODO: using global step value as provided by Tensorflow may mean avoiding
                # having to do batch_index + epoch * batches_in_epoch to keep track of total 
                # number of batch steps taken...
                
                # Choose which batches to use
                if pass_schedule[epoch] == 'Prioritised':
                    log.debug('===Running Ordered Pass===')
                    total_batches = len(prioritised_batch_sets)
                    is_custom_pass = True
                else:
                    # TODO stop doing extra computation for ordered batch if next is Full too
                    log.debug('===Running Standard Pass===')
                    total_batches = batches_in_epoch
                     # Keep track of samples and priority
                    # output volume is the output vector volume (e.g. probs/softmax = 1)
                    batch_prioritiser = SamplePrioritiser(choice_split_for_correct=0.25, 
                                                        output_volume=1, 
                                                        batch_size=self.args['batch_size'], 
                                                        batches_in_epoch=total_batches# batches_in_epoch
                                                       )
                    prioritised_batch_sets = []  # Will fill this during pass for ordered run
                    is_custom_pass = False
                    custom_batch = None
                    
                # Set sys_stats timer to now
                stats_timer = time.time()
                    
                for batch_index in range(total_batches):# range(batches_in_epoch):
                    # If doing a custom pass, need to use the 
                    # prioritised set of batches generated in full pass
                    if is_custom_pass:
                        # TODO need to create new batches from the prioritised batch sets
                        # Currently just taking from the wrong examples and training on those only
                        custom_batch = prioritised_batch_sets[batch_index]
                    
                    # Capture Test results
                    if batch_index % 50 == 0:
                        summary, acc = sess.run([merger, accuracy], feed_dict=feed_dict(False))
                        test_writer.add_summary(summary, batch_index + epoch * batches_in_epoch)
                        log.debug('== Testing - Accuracy at batch step %s: %s =='% (batch_index + epoch * batches_in_epoch, acc))
                    
                    # Training:
                    # Run training and obtain summaries
                    # Also capture the expected vs predicted output,
                    # necessary for new batch creation
                    log.debug('== TRAINING - Mode: {} - Batch: {} - Total Batches: {} =='.format(
                        pass_schedule[epoch], batch_index, batch_index + epoch * batches_in_epoch)
                    )
                    if batch_index % 100 == 99:
                        # Capture graph metadata, e.g. computation time per operation
                        # https://www.tensorflow.org/get_started/graph_viz
                        run_options = tf.RunOptions(trace_level=tf.RunOptions.FULL_TRACE)
                        run_metadata = tf.RunMetadata()
                        summary, _, target, predicted, samples = sess.run(
                            [merger, train_step, target_output, predicted_output, x], 
                            feed_dict=feed_dict(True, custom=is_custom_pass, custom_batch=custom_batch),
                            options=run_options,
                            run_metadata=run_metadata
                        )
                        train_writer.add_run_metadata(run_metadata, 'step {}'.format(batch_index + epoch * batches_in_epoch))
                        train_writer.add_summary(summary, batch_index + epoch * batches_in_epoch)
                        
                        # Custom System Stats
                        sys_stats_writer.calc_and_write_stats(sess, batch_index + epoch*batches_in_epoch, time.time() - stats_timer)
                        stats_timer = time.time()
                    else:
                        summary, _, target, predicted, samples = sess.run(
                            [merger, train_step, target_output, predicted_output, x],
                            feed_dict=feed_dict(True, custom=is_custom_pass, custom_batch=custom_batch)
                        )
                        train_writer.add_summary(summary, batch_index + epoch * batches_in_epoch)

                    # Check if we are in a Full (standard batching) pass
                    # if yes, then have to create the ordered batches
                    # ready for a prioritised batching pass
                    if not is_custom_pass:
                        batch_prioritiser.prioritise_samples(
                            samples, 
                            predicted, 
                            target, 
                            (batches_in_epoch-batch_index)/batches_in_epoch,
                        )
                
                
                log.debug('== Reached End of Epoch, Number: {} =='.format(epoch))
                
                if not is_custom_pass:
                    log.debug('==Generating prioritised batches==')
                    prioritised_batch_sets = batch_prioritiser.generate_prioritised_batches()

                # Test progress
                log.debug('== TESTING ==')
                summary, acc = sess.run([merger, accuracy], feed_dict=feed_dict(False))
                test_writer.add_summary(summary, batch_index + epoch * batches_in_epoch)
                log.debug('Test Set -- End of Epoch: {} -- Accuracy: {}'.format(epoch, acc))
            
            log.info('===Reached End of Scheduled Passes===')
            Reporter.save_checkpoint(sess)
            Reporter.save_model_meta()
            
            sess.close

# %% [markdown]
# ## Helper - Prioritiser

# %%
"""Prioritise samples and create new prioritised batches"""
import tensorflow as tf
import numpy as np

from operator import itemgetter
import random

from supernn.admin import Log; log = Log.get_logger(__name__)

class SamplePrioritiser(object):
    # TODO - May need to write to temporary files to save RAM
    
    
    
    def __init__(self, choice_split_for_correct, output_volume, batch_size, batches_in_epoch): 
        """
        Properties:
            choice_split_for_correct: Chance of choosing from correct samples 
                bucket over wrong samples
            output_volume: the output vector volume. Used to get an idea for 
                distance relative to max distance between prediction and target
            batch_size: size of the batches to output
            batches_in_epoch: number of batches in an epoch. Will aim to make this many
                output batches
        """
        self.output_volume = output_volume
        self.batch_size = batch_size
        self.batches_in_epoch = batches_in_epoch
        
        # specify weight boost importance of wrong over right classification
        self.choice_boundry = choice_split_for_correct
        
        # list: [(input, target), rank] - rank for ordering
        self.correct_samples_priorities_labels = []  
        self.wrong_samples_priorities_labels = []  # list of tuples
    
    def prioritise_samples(self, inputs, predicted, targets, percent_of_epoch):
        for i in range(len(targets)):
            elementwise_abs_dist = np.absolute(np.subtract(predicted[i],targets[i]))
            dist = np.sum(elementwise_abs_dist)
            # Wrong case
            if tf.equal(tf.argmax(predicted[i],1) != tf.argmax(targets[i], 1)):
                # Rank by amount wrong
                # high dist means high rank, but rank low to highest, so invert
                rank = 1/dist
                self.wrong_samples_priorities_labels.append(
                    [(inputs[i], targets[i]), rank]
                    )
                
            # Correct Case
            else:
                # Rank by amount right
                # dist = 0 means most correct. Lowest rank so highest value assigned
                rank = self.output_volume*2 - dist
                
                self.correct_samples_priorities_labels.append(
                    [(inputs[i], targets[i]), rank]
                    )
    
    def sort_sample_lists_by_rank(self):
        self.wrong_samples_priorities_labels = sorted(self.wrong_samples_priorities_labels, key=itemgetter(1))
        self.correct_samples_priorities_labels = sorted(self.correct_samples_priorities_labels, key=itemgetter(1))
        log.debug('=wrong samples: {} - right samples: {}='.format(
            len(self.wrong_samples_priorities_labels), len(self.correct_samples_priorities_labels) 
        ))
        
    def correct_sample_generator(self):
        for el in self.correct_samples_priorities_labels:
            yield el[0][0], el[0][1]
    
    def wrong_sample_generator(self):
        for el in self.wrong_samples_priorities_labels:
            yield el[0][0], el[0][1]
        
    def generate_prioritised_batches(self):
        """Generate prioritised batches
        Depends on:
            - the choice likelihood of right vs wrong
            - The rank of the samples within each list
        """
        self.sort_sample_lists_by_rank()
        correct_gen = self.correct_sample_generator()
        wrong_gen = self.wrong_sample_generator()
        
        wrong_gen_stop = False
        right_gen_stop = False
        
        batches_for_epoch = []
        while len(batches_for_epoch) < self.batches_in_epoch:
            sample_batch = []
            label_batch = []
            while len(sample_batch) < self.batch_size:
                choice_option = random.random()  # sample prob
                try:
                    if ((choice_option > self.choice_boundry and 
                            not wrong_gen_stop) or right_gen_stop):
#                     if (not wrong_gen_stop) or right_gen_stop:
                        # choose from wrong samples
                        wr = True
                        x, y = next(wrong_gen)
                    else:
                        wr = False
                        # choose from right samples
                        x, y = next(correct_gen)
                except StopIteration:
                    wrong_gen_stop = wr
                    right_gen_stop = not wr
                else:            
                    sample_batch.append(x)
                    label_batch.append(y)
                    
            batches_for_epoch.append((np.array(sample_batch), np.array(label_batch)))
        
        return batches_for_epoch

# %% [markdown]
# ## Main

# %% [markdown]
# ### Script

# %%
runner = Runner(args['config_path'], 'experiment_error_ordering').run()
# Out:
# 22:51:01 [supernn.admin.configuration] [DEBUG   ] : Extracting parameters for experiment_error_ordering from path ./config.ini
# 22:51:01 [supernn.admin.experiment] [DEBUG   ] : Starting experiment with config <Section: experiment_error_ordering>
# 22:51:01 [__main__            ] [INFO    ] : ===Parsing Experiment Config===
# 22:51:01 [__main__            ] [DEBUG   ] : Running experiment with args: {'dataset': 'MNIST', 'conv2d_1': {'x': 5, 'y': 5, 'channels': 1, 'features': 32, 'activation': <function relu at 0x7f48464c9840>}, 'conv2d_2': {'x': 5, 'y': 5, 'channels': 32, 'features': 64, 'activation': <function relu at 0x7f48464c9840>}, 'fcon_1': {'nodes': 1024, 'activation': <function relu at 0x7f48464c9840>}, 'learning_rate': 0.01, 'batch_size': 100, 'max_steps': 600, 'optimiser': 'ADAM', 'name': 'conv_lr_0.01'}
# 22:51:01 [__main__            ] [DEBUG   ] : experiment config: {'dataset': 'MNIST', 'conv2d_1': {'x': 5, 'y': 5, 'channels': 1, 'features': 32, 'activation': <function relu at 0x7f48464c9840>}, 'conv2d_2': {'x': 5, 'y': 5, 'channels': 32, 'features': 64, 'activation': <function relu at 0x7f48464c9840>}, 'fcon_1': {'nodes': 1024, 'activation': <function relu at 0x7f48464c9840>}, 'learning_rate': 0.01, 'batch_size': 100, 'max_steps': 600, 'optimiser': 'ADAM', 'name': 'conv_lr_0.01'}
# 22:51:01 [supernn.datasets.data_loader] [INFO    ] : Loading MNIST data to directory ./MNIST_data
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# 22:51:08 [__main__            ] [DEBUG   ] : ===Constructing Graph===
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# structure: ('input', <supernn.nn.layers.InputLayer object at 0x7f483ce059e8>)
# depth: 0
# class props: <supernn.nn.layers.InputLayer object at 0x7f483ce059e8>
# adding input layer
# setting input to conv2d shape
# structure: ('conv2d', <supernn.nn.layers.Convolution2D object at 0x7f483ce052b0>)
# depth: 1
# class props: <supernn.nn.layers.Convolution2D object at 0x7f483ce052b0>
# adding conv2d layer
# structure: ('conv2d', <supernn.nn.layers.Convolution2D object at 0x7f483ce05278>)
# depth: 2
# class props: <supernn.nn.layers.Convolution2D object at 0x7f483ce05278>
# adding conv2d layer
# structure: ('fully_connected', <supernn.nn.layers.FullyConnected object at 0x7f483ce051d0>)
# depth: 3
# class props: <supernn.nn.layers.FullyConnected object at 0x7f483ce051d0>
# adding fully connected layer
# 22:51:08 [__main__            ] [INFO    ] : ===Assigning metrics===
# 22:51:08 [__main__            ] [INFO    ] : ===Preparing Session and Running===
# structure: ('output', <supernn.nn.layers.OutputLayer object at 0x7f483ce05a90>)
# depth: 4
# class props: <supernn.nn.layers.OutputLayer object at 0x7f483ce05a90>
# adding output layer
# 22:51:09 [__main__            ] [DEBUG   ] : ===Running Standard Pass===
# 22:51:16 [__main__            ] [DEBUG   ] : == Testing - Accuracy at batch step 0: 0.0913 ==
# 22:51:16 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 0 - Total Batches: 0 ==
# 22:51:16 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 1 - Total Batches: 1 ==
# 22:51:17 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 2 - Total Batches: 2 ==
# 22:51:17 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 3 - Total Batches: 3 ==
# 22:51:18 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 4 - Total Batches: 4 ==
# 22:51:18 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 5 - Total Batches: 5 ==
# 22:51:18 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 6 - Total Batches: 6 ==
# 22:51:19 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 7 - Total Batches: 7 ==
# 22:51:19 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 8 - Total Batches: 8 ==
# 22:51:20 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 9 - Total Batches: 9 ==
# 22:51:21 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 10 - Total Batches: 10 ==
# 22:51:21 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 11 - Total Batches: 11 ==
# 22:51:22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 12 - Total Batches: 12 ==
# 22:51:22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 13 - Total Batches: 13 ==
# 22:51:23 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 14 - Total Batches: 14 ==
# 22:51:23 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 15 - Total Batches: 15 ==
# 22:51:24 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 16 - Total Batches: 16 ==
# 22:51:24 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 17 - Total Batches: 17 ==
# 22:51:25 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 18 - Total Batches: 18 ==
# 22:51:26 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 19 - Total Batches: 19 ==
# 22:51:26 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 20 - Total Batches: 20 ==
# 22:51:27 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 21 - Total Batches: 21 ==
# 22:51:27 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 22 - Total Batches: 22 ==
# 22:51:28 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 23 - Total Batches: 23 ==
# 22:51:28 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 24 - Total Batches: 24 ==
# 22:51:29 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 25 - Total Batches: 25 ==
# 22:51:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 26 - Total Batches: 26 ==
# 22:51:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 27 - Total Batches: 27 ==
# 22:51:31 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 28 - Total Batches: 28 ==
# 22:51:31 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 29 - Total Batches: 29 ==
# 22:51:32 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 30 - Total Batches: 30 ==
# 22:51:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 31 - Total Batches: 31 ==
# 22:51:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 32 - Total Batches: 32 ==
# 22:51:34 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 33 - Total Batches: 33 ==
# 22:51:35 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 34 - Total Batches: 34 ==
# 22:51:35 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 35 - Total Batches: 35 ==
# 22:51:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 36 - Total Batches: 36 ==
# 22:51:37 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 37 - Total Batches: 37 ==
# 22:51:37 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 38 - Total Batches: 38 ==
# 22:51:38 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 39 - Total Batches: 39 ==
# 22:51:39 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 40 - Total Batches: 40 ==
# 22:51:39 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 41 - Total Batches: 41 ==
# 22:51:40 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 42 - Total Batches: 42 ==
# 22:51:41 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 43 - Total Batches: 43 ==
# 22:51:42 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 44 - Total Batches: 44 ==
# 22:51:43 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 45 - Total Batches: 45 ==
# 22:51:43 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 46 - Total Batches: 46 ==
# 22:51:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 47 - Total Batches: 47 ==
# 22:51:45 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 48 - Total Batches: 48 ==
# 22:51:45 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 49 - Total Batches: 49 ==
# 22:51:52 [__main__            ] [DEBUG   ] : == Testing - Accuracy at batch step 50: 0.8422 ==
# 22:51:52 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 50 - Total Batches: 50 ==
# 22:51:53 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 51 - Total Batches: 51 ==
# 22:51:53 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 52 - Total Batches: 52 ==
# 22:51:54 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch:
22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 252 - Total Batches: 252 ==
# 22:57:24 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 253 - Total Batches: 253 ==
# 22:57:27 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 254 - Total Batches: 254 ==
# 22:57:29 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 255 - Total Batches: 255 ==
# 22:57:31 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 256 - Total Batches: 256 ==
# 22:57:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 257 - Total Batches: 257 ==
# 22:57:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 258 - Total Batches: 258 ==
# 22:57:38 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 259 - Total Batches: 259 ==
# 22:57:40 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 260 - Total Batches: 260 ==
# 22:57:42 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 261 - Total Batches: 261 ==
# 22:57:45 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 262 - Total Batches: 262 ==
# 22:57:47 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 263 - Total Batches: 263 ==
# 22:57:49 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 264 - Total Batches: 264 ==
# 22:57:51 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 265 - Total Batches: 265 ==
# 22:57:54 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 266 - Total Batches: 266 ==
# 22:57:56 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 267 - Total Batches: 267 ==
# 22:57:58 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 268 - Total Batches: 268 ==
# 22:58:00 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 269 - Total Batches: 269 ==
# 22:58:03 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 270 - Total Batches: 270 ==
# 22:58:05 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 271 - Total Batches: 271 ==
# 22:58:08 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 272 - Total Batches: 272 ==
# 22:58:10 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 273 - Total Batches: 273 ==
# 22:58:12 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 274 - Total Batches: 274 ==
# 22:58:15 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 275 - Total Batches: 275 ==
# 22:58:17 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 276 - Total Batches: 276 ==
# 22:58:19 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 277 - Total Batches: 277 ==
# 22:58:22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 278 - Total Batches: 278 ==
# 22:58:24 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 279 - Total Batches: 279 ==
# 22:58:27 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 280 - Total Batches: 280 ==
# 22:58:29 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 281 - Total Batches: 281 ==
# 22:58:32 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 282 - Total Batches: 282 ==
# 22:58:34 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 283 - Total Batches: 283 ==
# 22:58:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 284 - Total Batches: 284 ==
# 22:58:39 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 285 - Total Batches: 285 ==
# 22:58:41 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 286 - Total Batches: 286 ==
# 22:58:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 287 - Total Batches: 287 ==
# 22:58:46 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 288 - Total Batches: 288 ==
# 22:58:49 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 289 - Total Batches: 289 ==
# 22:58:51 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 290 - Total Batches: 290 ==
# 22:58:54 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 291 - Total Batches: 291 ==
# 22:58:56 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 292 - Total Batches: 292 ==
# 22:58:59 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 293 - Total Batches: 293 ==
# 22:59:02 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 294 - Total Batches: 294 ==
# 22:59:05 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 295 - Total Batches: 295 ==
# 22:59:07 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 296 - Total Batches: 296 ==
# 22:59:10 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 297 - Total Batches: 297 ==
# 22:59:12 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 298 - Total Batches: 298 ==
# 22:59:15 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 299 - Total Batches: 299 ==
# 22:59:25 [__main__            ] [DEBUG   ] : == Testing - Accuracy at batch step 300: 0.9465 ==
# 22:59:25 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 300 - Total Batches: 300 ==
# 22:59:25 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 301 - Total Batches: 301 ==
# 22:59:28 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 302 - Total Batches: 302 ==
# 22:59:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 303 - Total Batches: 303 ==
# 22:59:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 304 - Total Batches: 304 ==
# 22:59:35 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 305 - Total Batches: 305 ==
# 22:59:38 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 306 - Total Batches: 306 ==
# 22:59:40 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 307 - Total Batches: 307 ==
# 22:59:43 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 308 - Total Batches: 308 ==
# 22:59:45 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 309 - Total Batches: 309 ==
# 22:59:48 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 310 - Total Batches: 310 ==
# 22:59:50 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 311 - Total Batches: 311 ==
# 22:59:53 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 312 - Total Batches: 312 ==
# 22:59:56 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 313 - Total Batches: 313 ==
# 22:59:58 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 314 - Total Batches: 314 ==
# 23:00:01 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 315 - Total Batches: 315 ==
# 23:00:03 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 316 - Total Batches: 316 ==
# 23:00:06 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 317 - Total Batches: 317 ==
# 23:00:08 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 318 - Total Batches: 318 ==
# 23:00:11 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 319 - Total Batches: 319 ==
# 23:00:14 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 320 - Total Batches: 320 ==
# 23:00:16 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 321 - Total Batches: 321 ==
# 23:00:19 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 322 - Total Batches: 322 ==
# 23:00:22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 323 - Total Batches: 323 ==
# 23:00:24 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 324 - Total Batches: 324 ==
# 23:00:27 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 325 - Total Batches: 325 ==
# 23:00:29 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 326 - Total Batches: 326 ==
# 23:00:32 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 327 - Total Batches: 327 ==
# 23:00:35 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 328 - Total Batches: 328 ==
# 23:00:37 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 329 - Total Batches: 329 ==
# 23:00:40 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 330 - Total Batches: 330 ==
# 23:00:43 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 331 - Total Batches: 331 ==
# 23:00:45 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 332 - Total Batches: 332 ==
# 23:00:48 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 333 - Total Batches: 333 ==
# 23:00:51 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 334 - Total Batches: 334 ==
# 23:00:54 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 335 - Total Batches: 335 ==
# 23:00:56 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 336 - Total Batches: 336 ==
# 23:00:59 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 337 - Total Batches: 337 ==
# 23:01:02 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 338 - Total Batches: 338 ==
# 23:01:05 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 339 - Total Batches: 339 ==
# 23:01:08 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 340 - Total Batches: 340 ==
# 23:01:11 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 341 - Total Batches: 341 ==
# 23:01:13 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 342 - Total Batches: 342 ==
# 23:01:16 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 343 - Total Batches: 343 ==
# 23:01:19 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 344 - Total Batches: 344 ==
# 23:01:22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 345 - Total Batches: 345 ==
# 23:01:25 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 346 - Total Batches: 346 ==
# 23:01:27 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 347 - Total Batches: 347 ==
# 23:01:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 348 - Total Batches: 348 ==
# 23:01:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 349 - Total Batches: 349 ==
# 23:01:44 [__main__            ] [DEBUG   ] : == Testing - Accuracy at batch step 350: 0.957 ==
# 23:01:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 350 - Total Batches: 350 ==
# 23:01:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 351 - Total Batches: 351 ==
# 23:01:47 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 352 - Total Batches: 352 ==
# 23:01:50 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 353 - Total Batches: 353 ==
# 23:01:53 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 354 - Total Batches: 354 ==
# 23:01:55 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 355 - Total Batches: 355 ==
# 23:01:58 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 356 - Total Batches: 356 ==
# 23:02:01 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 357 - Total Batches: 357 ==
# 23:02:04 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 358 - Total Batches: 358 ==
# 23:02:07 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 359 - Total Batches: 359 ==
# 23:02:10 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 360 - Total Batches: 360 ==
# 23:02:12 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 361 - Total Batches: 361 ==
# 23:02:15 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 362 - Total Batches: 362 ==
# 23:02:18 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 363 - Total Batches: 363 ==
# 23:02:21 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 364 - Total Batches: 364 ==
# 23:02:24 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 365 - Total Batches: 365 ==
# 23:02:27 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 366 - Total Batches: 366 ==
# 23:02:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 367 - Total Batches: 367 ==
# 23:02:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 368 - Total Batches: 368 ==
# 23:02:37 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 369 - Total Batches: 369 ==
# 23:02:39 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 370 - Total Batches: 370 ==
# 23:02:42 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 371 - Total Batches: 371 ==
# 23:02:45 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 372 - Total Batches: 372 ==
# 23:02:48 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 373 - Total Batches: 373 ==
# 23:02:51 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 374 - Total Batches: 374 ==
# 23:02:54 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 375 - Total Batches: 375 ==
# 23:02:57 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 376 - Total Batches: 376 ==
# 23:03:00 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 377 - Total Batches: 377 ==
# 23:03:03 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 378 - Total Batches: 378 ==
# 23:03:06 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 379 - Total Batches: 379 ==
# 23:03:09 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 380 - Total Batches: 380 ==
# 23:03:12 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 381 - Total Batches: 381 ==
# 23:03:15 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 382 - Total Batches: 382 ==
# 23:03:18 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 383 - Total Batches: 383 ==
# 23:03:21 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 384 - Total Batches: 384 ==
# 23:03:24 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 385 - Total Batches: 385 ==
# 23:03:27 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 386 - Total Batches: 386 ==
# 23:03:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 387 - Total Batches: 387 ==
# 23:03:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 388 - Total Batches: 388 ==
# 23:03:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 389 - Total Batches: 389 ==
# 23:03:39 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 390 - Total Batches: 390 ==
# 23:03:43 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 391 - Total Batches: 391 ==
# 23:03:46 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 392 - Total Batches: 392 ==
# 23:03:49 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 393 - Total Batches: 393 ==
# 23:03:52 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 394 - Total Batches: 394 ==
# 23:03:55 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 395 - Total Batches: 395 ==
# 23:03:58 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 396 - Total Batches: 396 ==
# 23:04:01 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 397 - Total Batches: 397 ==
# 23:04:05 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 398 - Total Batches: 398 ==
# 23:04:08 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 399 - Total Batches: 399 ==
# 23:04:19 [__main__            ] [DEBUG   ] : == Testing - Accuracy at batch step 400: 0.954 ==
# 23:04:19 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 400 - Total Batches: 400 ==
# 23:04:20 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 401 - Total Batches: 401 ==
# 23:04:23 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 402 - Total Batches: 402 ==
# 23:04:26 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 403 - Total Batches: 403 ==
# 23:04:29 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 404 - Total Batches: 404 ==
# 23:04:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 405 - Total Batches: 405 ==
# 23:04:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 406 - Total Batches: 406 ==
# 23:04:39 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 407 - Total Batches: 407 ==
# 23:04:43 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 408 - Total Batches: 408 ==
# 23:04:46 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 409 - Total Batches: 409 ==
# 23:04:49 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 410 - Total Batches: 410 ==
# 23:04:53 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 411 - Total Batches: 411 ==
# 23:04:56 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 412 - Total Batches: 412 ==
# 23:04:59 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 413 - Total Batches: 413 ==
# 23:05:02 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 414 - Total Batches: 414 ==
# 23:05:06 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 415 - Total Batches: 415 ==
# ...
# 23:57:08 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 410 - Total Batches: 1510 ==
# 23:57:15 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 411 - Total Batches: 1511 ==
# 23:57:23 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 412 - Total Batches: 1512 ==
# 23:57:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 413 - Total Batches: 1513 ==
# 23:57:37 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 414 - Total Batches: 1514 ==
# 23:57:45 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 415 - Total Batches: 1515 ==
# 23:57:52 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 416 - Total Batches: 1516 ==
# 23:57:59 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 417 - Total Batches: 1517 ==
# 23:58:07 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 418 - Total Batches: 1518 ==
# 23:58:14 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 419 - Total Batches: 1519 ==
# 23:58:22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 420 - Total Batches: 1520 ==
# 23:58:29 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 421 - Total Batches: 1521 ==
# 23:58:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 422 - Total Batches: 1522 ==
# 23:58:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 423 - Total Batches: 1523 ==
# 23:58:51 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 424 - Total Batches: 1524 ==
# 23:58:58 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 425 - Total Batches: 1525 ==
# 23:59:06 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 426 - Total Batches: 1526 ==
# 23:59:14 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 427 - Total Batches: 1527 ==
# 23:59:21 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 428 - Total Batches: 1528 ==
# 23:59:29 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 429 - Total Batches: 1529 ==
# 23:59:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 430 - Total Batches: 1530 ==
# 23:59:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 431 - Total Batches: 1531 ==
# 23:59:51 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 432 - Total Batches: 1532 ==
# 23:59:59 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 433 - Total Batches: 1533 ==
# 00:00:06 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 434 - Total Batches: 1534 ==
# 00:00:14 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 435 - Total Batches: 1535 ==
# 00:00:21 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 436 - Total Batches: 1536 ==
# 00:00:29 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 437 - Total Batches: 1537 ==
# 00:00:37 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 438 - Total Batches: 1538 ==
# 00:00:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 439 - Total Batches: 1539 ==
# 00:00:52 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 440 - Total Batches: 1540 ==
# 00:00:59 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 441 - Total Batches: 1541 ==
# 00:01:07 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 442 - Total Batches: 1542 ==
# 00:01:14 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 443 - Total Batches: 1543 ==
# 00:01:22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 444 - Total Batches: 1544 ==
# 00:01:29 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 445 - Total Batches: 1545 ==
# 00:01:37 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 446 - Total Batches: 1546 ==
# 00:01:45 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 447 - Total Batches: 1547 ==
# 00:01:52 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 448 - Total Batches: 1548 ==
# 00:02:00 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 449 - Total Batches: 1549 ==
# 00:02:20 [__main__            ] [DEBUG   ] : == Testing - Accuracy at batch step 1550: 0.9779 ==
# 00:02:20 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 450 - Total Batches: 1550 ==
# 00:02:21 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 451 - Total Batches: 1551 ==
# 00:02:29 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 452 - Total Batches: 1552 ==
# 00:02:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 453 - Total Batches: 1553 ==
# 00:02:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 454 - Total Batches: 1554 ==
# 00:02:52 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 455 - Total Batches: 1555 ==
# 00:02:59 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 456 - Total Batches: 1556 ==
# 00:03:07 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 457 - Total Batches: 1557 ==
# 00:03:15 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 458 - Total Batches: 1558 ==
# 00:03:22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 459 - Total Batches: 1559 ==
# 00:03:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 460 - Total Batches: 1560 ==
# 00:03:38 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 461 - Total Batches: 1561 ==
# 00:03:45 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 462 - Total Batches: 1562 ==
# 00:03:53 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 463 - Total Batches: 1563 ==
# 00:04:00 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 464 - Total Batches: 1564 ==
# 00:04:08 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 465 - Total Batches: 1565 ==
# 00:04:15 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 466 - Total Batches: 1566 ==
# 00:04:23 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 467 - Total Batches: 1567 ==
# 00:04:31 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 468 - Total Batches: 1568 ==
# 00:04:38 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 469 - Total Batches: 1569 ==
# 00:04:46 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 470 - Total Batches: 1570 ==
# 00:04:54 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 471 - Total Batches: 1571 ==
# 00:05:02 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 472 - Total Batches: 1572 ==
# 00:05:09 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 473 - Total Batches: 1573 ==
# 00:05:17 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 474 - Total Batches: 1574 ==
# 00:05:25 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 475 - Total Batches: 1575 ==
# 00:05:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 476 - Total Batches: 1576 ==
# 00:05:41 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 477 - Total Batches: 1577 ==
# 00:05:49 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 478 - Total Batches: 1578 ==
# 00:05:57 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 479 - Total Batches: 1579 ==
# 00:06:05 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 480 - Total Batches: 1580 ==
# 00:06:13 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 481 - Total Batches: 1581 ==
# 00:06:20 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 482 - Total Batches: 1582 ==
# 00:06:28 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 483 - Total Batches: 1583 ==
# 00:06:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 484 - Total Batches: 1584 ==
# 00:06:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 485 - Total Batches: 1585 ==
# 00:06:51 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 486 - Total Batches: 1586 ==
# 00:06:59 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 487 - Total Batches: 1587 ==
# 00:07:07 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 488 - Total Batches: 1588 ==
# 00:07:15 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 489 - Total Batches: 1589 ==
# 00:07:23 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 490 - Total Batches: 1590 ==
# 00:07:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 491 - Total Batches: 1591 ==
# 00:07:38 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 492 - Total Batches: 1592 ==
# 00:07:46 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 493 - Total Batches: 1593 ==
# 00:07:55 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 494 - Total Batches: 1594 ==
# 00:08:03 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 495 - Total Batches: 1595 ==
# 00:08:11 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 496 - Total Batches: 1596 ==
# 00:08:18 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 497 - Total Batches: 1597 ==
# 00:08:26 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 498 - Total Batches: 1598 ==
# 00:08:34 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 499 - Total Batches: 1599 ==
# 00:08:55 [__main__            ] [DEBUG   ] : == Testing - Accuracy at batch step 1600: 0.9785 ==
# 00:08:55 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 500 - Total Batches: 1600 ==
# 00:08:56 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 501 - Total Batches: 1601 ==
# 00:09:04 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 502 - Total Batches: 1602 ==
# 00:09:12 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 503 - Total Batches: 1603 ==
# 00:09:20 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 504 - Total Batches: 1604 ==
# 00:09:28 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 505 - Total Batches: 1605 ==
# 00:09:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 506 - Total Batches: 1606 ==
# 00:09:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 507 - Total Batches: 1607 ==
# 00:09:52 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 508 - Total Batches: 1608 ==
# 00:10:00 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 509 - Total Batches: 1609 ==
# 00:10:08 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 510 - Total Batches: 1610 ==
# 00:10:17 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 511 - Total Batches: 1611 ==
# 00:10:25 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 512 - Total Batches: 1612 ==
# 00:10:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 513 - Total Batches: 1613 ==
# 00:10:41 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 514 - Total Batches: 1614 ==
# 00:10:50 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 515 - Total Batches: 1615 ==
# 00:10:58 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 516 - Total Batches: 1616 ==
# 00:11:06 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 517 - Total Batches: 1617 ==
# 00:11:14 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 518 - Total Batches: 1618 ==
# 00:11:22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 519 - Total Batches: 1619 ==
# 00:11:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 520 - Total Batches: 1620 ==
# 00:11:39 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 521 - Total Batches: 1621 ==
# 00:11:47 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 522 - Total Batches: 1622 ==
# 00:11:55 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 523 - Total Batches: 1623 ==
# 00:12:03 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 524 - Total Batches: 1624 ==
# 00:12:11 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 525 - Total Batches: 1625 ==
# 00:12:19 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 526 - Total Batches: 1626 ==
# 00:12:27 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 527 - Total Batches: 1627 ==
# 00:12:36 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 528 - Total Batches: 1628 ==
# 00:12:44 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 529 - Total Batches: 1629 ==
# 00:12:52 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 530 - Total Batches: 1630 ==
# 00:13:00 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 531 - Total Batches: 1631 ==
# 00:13:08 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 532 - Total Batches: 1632 ==
# 00:13:16 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 533 - Total Batches: 1633 ==
# 00:13:24 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 534 - Total Batches: 1634 ==
# 00:13:33 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 535 - Total Batches: 1635 ==
# 00:13:41 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 536 - Total Batches: 1636 ==
# 00:13:49 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 537 - Total Batches: 1637 ==
# 00:13:57 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 538 - Total Batches: 1638 ==
# 00:14:05 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 539 - Total Batches: 1639 ==
# 00:14:13 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 540 - Total Batches: 1640 ==
# 00:14:22 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 541 - Total Batches: 1641 ==
# 00:14:30 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 542 - Total Batches: 1642 ==
# 00:14:38 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 543 - Total Batches: 1643 ==
# 00:14:46 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 544 - Total Batches: 1644 ==
# 00:14:55 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 545 - Total Batches: 1645 ==
# 00:15:03 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 546 - Total Batches: 1646 ==
# 00:15:11 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 547 - Total Batches: 1647 ==
# 00:15:20 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 548 - Total Batches: 1648 ==
# 00:15:28 [__main__            ] [DEBUG   ] : == TRAINING - Mode: Full - Batch: 549 - Total Batches: 1649 ==
# 00:15:36 [__main__            ] [DEBUG   ] : == Reached End of Epoch, Number: 2 ==
# 00:15:36 [__main__            ] [DEBUG   ] : ==Generating prioritised batches==
# 00:15:36 [__main__            ] [DEBUG   ] : =wrong samples: 55000 - right samples: 0=
# 00:15:37 [__main__            ] [DEBUG   ] : == TESTING ==
# 00:15:50 [__main__            ] [DEBUG   ] : Test Set -- End of Epoch: 2 -- Accuracy: 0.9805001020431519
# 00:15:50 [__main__            ] [INFO    ] : ===Reached End of Scheduled Passes===
# 00:16:53 [__main__            ] [DEBUG   ] : Finished experiment after 5152.08s
# 00:16:53 [__main__            ] [DEBUG   ] : Finished experiments after 5152.08s
